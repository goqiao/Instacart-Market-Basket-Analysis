# %%
import pandas as pd
import numpy as np
import shap
import xgboost
import matplotlib.pyplot as plt
import time
import mlflow
import seaborn as sns
sns.set_context('paper')
from utils import download_user_order_history, locate_by_uid_pid
from matplotlib import rcParams
rcParams.update({'figure.autolayout': True})

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
print(shap.__version__)
# Out:
# 0.41.0

# %%
start_time = time.time()
data_folder = 'data'
experiment_name = 'SHAP Force Plot'

# enter example
pid = 21333
uid = 125400
run_name = 'userid: {} productid: {}'.format(uid, pid)

# %%
# load model
xgb = xgboost.XGBClassifier()
xgb.load_model('{}/xgb_model.json'.format(data_folder))

# load data
train_full_features = pd.read_pickle('{}/train_full_features.pickle'.format(data_folder))

# %%
# select instance
instance = train_full_features.loc[(train_full_features.user_id==uid)&(train_full_features['product_id']==pid)]

# download
print(instance)
# download_user_order_history(uid, pid)

# drop columns
instance = instance.drop(columns=['order_id', 'user_id', 'product_id', 'reordered'])
features = train_full_features.drop(columns=['order_id', 'user_id', 'product_id', 'reordered'])
# Out:
#          user_id  order_id  product_id  reordered  up_num_purchases  \
# 3034949   125400   2136219       21333          0                 4
#
#          up_cart_order_mean  up_cart_order_std  up_cart_order_sum  \
# 3034949                 6.0           4.242641                 24
#
#          up_cart_order_min  up_cart_order_max  up_cart_order_median  \
# 3034949                  2                 11                   5.5
#
#          up_reorder_times  up_first_order  up_last_order  up_mean_order_num  \
# 3034949                 3               1             19               10.0
#
#          up_std_order_num  user_max_order  up_num_purchases_within5  \
# 3034949          7.393691              27                       0.0
#
#          up_purchase_ratio_within5  up_purchase_interval_days_mean  \
# 3034949                        0.0                       43.666668
#
#          up_purchase_interval_days_median  up_purchase_interval_days_max  \
# 3034949                              34.0                           94.0
#
#          up_purchase_interval_days_min  up_purchase_interval_days_mean_r5  \
# 3034949                            3.0                                NaN
#
#          up_purchase_interval_days_median_r5  \
# 3034949                                  NaN
#
#          up_purchase_interval_days_max_r5  up_purchase_interval_days_min_r5  \
# 3034949                               NaN                               NaN
#
#          up_purchase_proba  up_purhcase_proba_r5  up_num_days_not_purchase  \
# 3034949           0.115385                   NaN                      73.0
#
#          up_aisle_purchase_trend_d1  up_department_purchase_trend_d1  \
# 3034949                   -0.009768                          0.04823
#
#          up_substitute_num_purchases  up_subsitute_num_purchases_within5  \
# 3034949                          0.0                                 0.0
#
#          up_organic_substitute_num_purchases  \
# 3034949                                  0.0
#
#          up_organic_substitute_num_purchases_r5  up_purchases_dow_0  \
# 3034949                                     0.0                   1
#
#          up_purchases_dow_1  up_purchases_dow_2  up_purchases_dow_3  \
# 3034949                   1                   1                   0
#
#          up_purchases_dow_4  up_purchases_dow_5  up_purchases_dow_6  \
# 3034949                   0                   0                   1
#
#          up_norm_purchases_dow_0  up_norm_purchases_dow_1  \
# 3034949                     0.25                     0.25
#
#          up_norm_purchases_dow_2  up_norm_purchases_dow_3  \
# 3034949                     0.25                      0.0
#
#          up_norm_purchases_dow_4  up_norm_purchases_dow_5  \
# 3034949                      0.0                      0.0
#
#          up_norm_purchases_dow_6  up_purchases_pod_midnight  \
# 3034949                     0.25                          0
#
#          up_purchases_pod_morning  up_purchases_pod_night  \
# 3034949                         2                       1
#
#          up_purchases_pod_noon  up_norm_purchases_pod_midnight  \
# 3034949                      1                             0.0
#
#          up_norm_purchases_pod_morning  up_norm_purchases_pod_night  \
# 3034949                            0.5                         0.25
#
#          up_norm_purchases_pod_noon  user_age_days_on_platform  \
# 3034949                        0.25                      189.0
#
#          user_mean_days_order_interval  user_std_days_order_interval  \
# 3034949                       7.269231                      8.402655
#
#          user_total_orders  user_mean_order_dow  user_std_order_dow  \
# 3034949                 27             2.703704            2.430809
#
#          user_mean_order_hour  user_std_order_hour  user_product_total  \
# 3034949             14.851852             3.899741                 253
#
#          user_product_unique  aisle_nunique  user_department_unique  \
# 3034949                   81             39                      13
#
#          user_reorder_prod_total  user_order_num_sum_exclude_1st  \
# 3034949                    172.0                             240
#
#          user_reorder_ratio  user_days_not_purchase  uo_basket_size_mean  \
# 3034949            0.716667                    15.0              9.37037
#
#          uo_basket_size_std  uo_unique_aisle_mean  uo_unique_aisle_std  \
# 3034949            3.164079              8.259259             2.725839
#
#          uo_unique_department_mean  uo_unique_department_std  \
# 3034949                   5.444444                  1.577079
#
#          uo_reorered_products_mean  uo_reordered_products_std  \
# 3034949                    6.37037                   3.509856
#
#          uo_reorder_ratio_mean  uo_reorder_ratio_std  user_reorder_rate  \
# 3034949               0.686917               0.25598           0.679842
#
#          user_next_order_readiness  user_order_freq  \
# 3034949                   7.730769              7.0
#
#          user_basket_size_trend_d1  user_orders_days_interval_trend  \
# 3034949                   0.056777                         0.259463
#
#          users_organic_ratio  users_gluten_free_ratio  users_asian_food_ratio  \
# 3034949             0.047431                 0.007905                     0.0
#
#          users_organic_ratio_r5  users_gluten_free_ratio_r5  \
# 3034949                0.039216                         0.0
#
#          users_asian_food_ratio_r5  users_purchases_dow_0  \
# 3034949                        0.0                     67
#
#          users_purchases_dow_1  users_purchases_dow_2  users_purchases_dow_3  \
# 3034949                     43                     19                     32
#
#          users_purchases_dow_4  users_purchases_dow_5  users_purchases_dow_6  \
# 3034949                      0                     25                     67
#
#          users_norm_purchases_dow_0  users_norm_purchases_dow_1  \
# 3034949                    0.264822                     0.16996
#
#          users_norm_purchases_dow_2  users_norm_purchases_dow_3  \
# 3034949                    0.075099                    0.126482
#
#          users_norm_purchases_dow_4  users_norm_purchases_dow_5  \
# 3034949                         0.0                    0.098814
#
#          users_norm_purchases_dow_6  users_purchases_pod_midnight  \
# 3034949                    0.264822                             0
#
#          users_purchases_pod_morning  users_purchases_pod_night  \
# 3034949                           59                         60
#
#          users_purchases_pod_noon  users_norm_purchases_pod_midnight  \
# 3034949                       134                                0.0
#
#          users_norm_purchases_pod_morning  users_norm_purchases_pod_night  \
# 3034949                          0.233202                        0.237154
#
#          users_norm_purchases_pod_noon  p_num_purchases  p_unique_buyers  \
# 3034949                       0.529644            11179             4815
#
#          p_mean_add_cart_num  p_std_add_cart_num  p_reorder_rate  \
# 3034949             8.870024            7.148366        0.569282
#
#          p_sum_reordered  p_sum_secondtime_purchase  p_sum_onetime_purchase  \
# 3034949           6364.0                       2088                  4815.0
#
#          p_reorder_proba  p_avg_first_order_num  p_std_first_order_num  \
# 3034949         0.433645               8.517342              10.766436
#
#          p_avg_first_reorder_num  p_std_first_reorder_num  \
# 3034949                12.675287                12.590636
#
#          p_avg_first_reorder_diff  p_std_first_reorder_diff  \
# 3034949                  1.675389                  5.430064
#
#          p_num_purchases_per_user_mean  p_num_purchases_per_user_std  \
# 3034949                       2.321703                        2.7717
#
#          p_num_purchases_per_user_median  p_num_purchases_per_user_max  \
# 3034949                              1.0                            40
#
#          p_num_purchases_per_user_min  p_num_purchases_per_user_q20  \
# 3034949                             1                           1.0
#
#          p_num_purchases_per_user_q80  p_purchase_interval_days_mean  \
# 3034949                           3.0                      36.884979
#
#          p_purchase_interval_days_std  p_purchase_interval_days_median  \
# 3034949                     40.480498                             24.0
#
#          p_purchase_interval_days_q20  p_purchase_interval_days_q80  \
# 3034949                           9.0                          55.0
#
#          p_purchase_interval_days_max_woo  p_purchase_interval_days_min_woo  \
# 3034949                              98.5                               0.0
#
#          is_organic  is_gluten_free  is_asian  \
# 3034949       False           False     False
#
#          up_num_orders_since_last_purchase  up_overdue_days_mean  \
# 3034949                                  8            -29.333332
#
#          up_overdue_days_max  up_overdue_days_min  up_purchase_readiness  \
# 3034949                 21.0                 70.0               0.802198
#
#          up_num_purchases_diff_p_mean  up_num_purchases_diff_p_max  \
# 3034949                      1.678297                          -36
#
#          up_num_purchases_diff_p_min  up_num_purchases_diff_p_q20  \
# 3034949                            3                          3.0
#
#          up_num_purchases_diff_p_q80  up_readiness_p_mean  \
# 3034949                          1.0            36.115021
#
#          up_readiness_p_median  up_readiness_p_q20  up_readiness_p_q80  \
# 3034949                   49.0                64.0                18.0
#
#          up_readiness_p_max_woo  up_readiness_p_min_woo  up_readiness_p_range
# 3034949                   -25.5                    73.0              0.741117

# %%
# booster = xgb.get_booster()
# model_bytearray = booster.save_raw()[4:]
# booster.save_raw = lambda : model_bytearray

# %%
explainer = shap.TreeExplainer(xgb, model_output='probability', data=features.sample(frac=0.05, random_state=0).values.astype(np.float64))
# shap_values = explainer.shap_values(instance)
exp = explainer.expected_value
print(exp)
# Out:
# 0.0949343474798107

# %%
shap_values = explainer(instance)

# %%
print(instance.shape)
print(shap_values.shape)
# Out:
# (1, 162)
# (1, 162)

# %%
fig = shap.waterfall_plot(shap_values[0], show=False, max_display=6)
fig.set_size_inches(16, 8)
plt.tight_layout()
plt.savefig('data/waterfall_uid_{}_pid_{}'.format(uid, pid))
plt.show()
